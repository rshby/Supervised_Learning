# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from jcopml.plot import plot_missing_value

# %% [markdown]
# # Import Datasets

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("datasets/train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1

# %% [markdown]
# ## Number of columns and rows

# %%
df.shape
# Out:
# (2000, 21)

# %% [markdown]
# ## Correlation Matrix

# %%
from jcopml.plot import plot_correlation_matrix
plot_correlation_matrix(df, 'price_range', numeric_col=["battery_power", "clock_speed", "fc", 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time'])
# Out:
# interactive(children=(ToggleButtons(description='method', options=('spearman', 'kendall', 'pearson', 'pearson_…

# %% [markdown]
# Based on the correlation matrix results, we will only use four columns
# ### ---------------------------------------------------------------------------------------------------------------

# %%
kolom_yg_dipakai = ["battery_power", "ram", "px_height", "px_width", "price_range"]

# %%
df_new = df[kolom_yg_dipakai]

# %%
print(df_new.shape)
df_new
# Out:
# (2000, 5)
#       battery_power   ram  px_height  px_width  price_range
# 0               842  2549         20       756            1
# 1              1021  2631        905      1988            2
# 2               563  2603       1263      1716            2
# 3               615  2769       1216      1786            2
# 4              1821  1411       1208      1212            1
# ...             ...   ...        ...       ...          ...
# 1995            794   668       1222      1890            0
# 1996           1965  2032        915      1965            2
# 1997           1911  3057        868      1632            3
# 1998           1512   869        336       670            0
# 1999            510  3919        483       754            3
#
# [2000 rows x 5 columns]

# %% [markdown]
# ## Check Missing Value
# there is no missing value. Data ready for processing

# %%
plot_missing_value(df_new, return_df=True)
# Out:
#                missing_value    %
# battery_power              0  0.0
# ram                        0  0.0
# px_height                  0  0.0
# px_width                   0  0.0
# price_range                0  0.0

# %% [markdown]
# # Histogram

# %%
[print(df[x].describe(), "\n") for x in df_new.columns if x!='price_range']

f, axes = plt.subplots(2, 2, figsize=(17, 7), sharex=False)
sns.distplot( df["battery_power"], bins=100, color="blue", ax=axes[0, 0])
sns.distplot( df["ram"], bins=100, color="olive", ax=axes[0, 1])
sns.distplot( df["px_height"], bins=100, color="gold", ax=axes[1, 0])
sns.distplot( df["px_width"], bins=100, color="teal", ax=axes[1, 1])
# Out:
# count    2000.000000
# mean     1238.518500
# std       439.418206
# min       501.000000
# 25%       851.750000
# 50%      1226.000000
# 75%      1615.250000
# max      1998.000000
# Name: battery_power, dtype: float64
#
# count    2000.000000
# mean     2124.213000
# std      1084.732044
# min       256.000000
# 25%      1207.500000
# 50%      2146.500000
# 75%      3064.500000
# max      3998.000000
# Name: ram, dtype: float64
#
# count    2000.000000
# mean      645.108000
# std       443.780811
# min         0.000000
# 25%       282.750000
# 50%       564.000000
# 75%       947.250000
# max      1960.000000
# Name: px_height, dtype: float64
#
# count    2000.000000
# mean     1251.515500
# std       432.199447
# min       500.000000
# 25%       874.750000
# 50%      1247.000000
# 75%      1633.000000
# max      1998.000000
# Name: px_width, dtype: float64

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x=df["ram"], y=df["price_range"])

# %% [markdown]
# ## Check the relationship using Pairplot
# it can be seen that the most affecting parameter is the RAM column

# %%
sns.pairplot(df_new,hue='price_range')

# %% [markdown]
# # Datasets Splitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease

# %%
# Separate the features and target columns
X = df_new.drop(columns=["price_range"])
y = df_new["price_range"]

# Create data train and data test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1600, 4), (400, 4), (1600,), (400,))

# %% [markdown]
# # Modeling - SVM Classifier

# %%
from sklearn.svm import SVC 
from sklearn.model_selection import RandomizedSearchCV
from jcopml.tuning import grid_search_params as gsp

# %%
parameter_tune = {'algo__gamma': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__C': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__max_iter' : [100, 200, 300, 400, 500, 600]}

# %%
preprocessing = ColumnTransformer([
    ('numeric', num_pipe(), X_train.columns),
])

pipeline = Pipeline([
    ('prep', preprocessing),
    ('algo', SVC())
])

model = RandomizedSearchCV(pipeline, parameter_tune,cv=3, n_jobs=-1, verbose=1, n_iter=150)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 450 out of 450 | elapsed:   21.1s finished
# C:\Users\ROG\anaconda3\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=200).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# {'algo__max_iter': 200, 'algo__gamma': 0.001, 'algo__C': 1.0}
# 0.97 0.8974956257773469 0.91

# %% [markdown]
# ## Improve SVM Classifier with scalling, and transform

# %%
parameter_tune = {'algo__gamma': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__C': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__max_iter' : [100, 200, 300, 400, 500, 600]}

preprocessing = ColumnTransformer([
    ('numeric', num_pipe(scaling='standard', transform='yeo-johnson'), X_train.columns),
])

pipeline = Pipeline([
    ('prep', preprocessing),
    ('algo', SVC())
])

model = RandomizedSearchCV(pipeline, parameter_tune,cv=3, n_jobs=-1, verbose=1, n_iter=200)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# C:\Users\ROG\anaconda3\lib\site-packages\jcopml\pipeline\_pipeline.py:65: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:   22.7s finished
# {'algo__max_iter': 400, 'algo__gamma': 0.01, 'algo__C': 1000.0}
# 0.953125 0.951871839375265 0.9675
# C:\Users\ROG\anaconda3\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=400).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
parameter_tune = {'algo__gamma': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__C': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__max_iter' : [100, 200, 300, 400, 500, 600]}

preprocessing = ColumnTransformer([
    ('numeric', num_pipe(scaling='robust'), X_train.columns),
])

pipeline = Pipeline([
    ('prep', preprocessing),
    ('algo', SVC())
])

model = RandomizedSearchCV(pipeline, parameter_tune,cv=3, n_jobs=-1, verbose=1, n_iter=200)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   12.5s
# {'algo__max_iter': 200, 'algo__gamma': 0.001, 'algo__C': 1000.0}
# 0.95125 0.956250746604268 0.9725
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:   16.0s finished
# C:\Users\ROG\anaconda3\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=200).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# ## Improve SVM Classifier Poly

# %%
parameter_tune = {
'prep__numeric__poly__degree': [2, 3, 4],
 'prep__numeric__poly__interaction_only': [True, False],
'algo__gamma': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__C': [1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03],
'algo__max_iter' : [100, 200, 300, 400, 500, 600]}

# %%
preprocessing = ColumnTransformer([
    ('numeric', num_pipe(poly=2 ,scaling='robust'), X_train.columns),
])

pipeline = Pipeline([
    ('prep', preprocessing),
    ('algo', SVC())
])

model = RandomizedSearchCV(pipeline, parameter_tune,cv=3, n_jobs=-1, verbose=1, n_iter=200)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   17.5s
# {'prep__numeric__poly__interaction_only': True, 'prep__numeric__poly__degree': 2, 'algo__max_iter': 400, 'algo__gamma': 0.001, 'algo__C': 1000.0}
# 0.958125 0.9512546465136215 0.9675
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:   24.0s finished
# C:\Users\ROG\anaconda3\lib\site-packages\sklearn\svm\_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=400).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# # Evaluation

# %%
from jcopml.plot import plot_classification_report, plot_confusion_matrix, plot_roc_curve, plot_pr_curve

# %% [markdown]
# Classification Report

# %%
plot_classification_report(X_train, y_train, X_test, y_test, model, report=True)
# Out:
# Train report
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       400
#            1       0.95      0.96      0.95       400
#            2       0.94      0.94      0.94       400
#            3       0.96      0.96      0.96       400
#
#     accuracy                           0.96      1600
#    macro avg       0.96      0.96      0.96      1600
# weighted avg       0.96      0.96      0.96      1600
#
#
# Test report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       0.96      0.98      0.97       100
#            2       0.95      0.92      0.93       100
#            3       0.96      0.97      0.97       100
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400

# %% [markdown]
# Plot Confussion Matrix

# %%
plot_confusion_matrix(X_train, y_train, X_test, y_test, model)
