# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Datasets

# %%
df = pd.read_csv("datasets/City_day.csv")

# ambil data yang data targetnya tidak kosong
df = df[df["Air_quality"].notna()]

# reset index karena jumlah data pasti berkurang
df = df.reset_index()

# hapus kolom index lama
df = df.drop(columns="index")

# tampilkan dataframe
df
# Out:
#                      City       Date   PM2.5   PM10     NO    NO2    NOx  \
# 0               Ahmedabad  1/29/2015   83.13    NaN   6.93  28.71  33.72
# 1               Ahmedabad  1/30/2015   79.84    NaN  13.85  28.68  41.08
# 2               Ahmedabad  1/31/2015   94.52    NaN  24.39  32.66  52.61
# 3               Ahmedabad   2/1/2015  135.99    NaN  43.48  42.08  84.57
# 4               Ahmedabad   2/2/2015  178.33    NaN  54.56  35.31  72.80
# ...                   ...        ...     ...    ...    ...    ...    ...
# 21932  Thiruvananthapuram  4/27/2020   14.13  34.27   5.60   8.98  12.48
# 21933  Thiruvananthapuram  4/28/2020   23.84  44.32   6.27  10.01  13.80
# 21934  Thiruvananthapuram  4/29/2020   18.54  34.48   6.17   9.67  13.35
# 21935  Thiruvananthapuram  4/30/2020   20.57  48.19   6.28   9.52  13.56
# 21936  Thiruvananthapuram   5/1/2020   17.58  37.49   2.56   7.84   9.34
#
#         NH3     CO    SO2      O3  Benzene  Toluene  Xylene    AQI  \
# ...

# %% [markdown]
# Karena dalam siklus angin biasanya tahun dan bulan juga dapat mempengaruhi kualitas udara, oleh karena itu dalam kolom Date akan kita lakukan ekstraksi fitur dengan mengambil data tahun dan data bulan.

# %%
# buat kolom year yang berisi data tahun hasil ekstraksi kolom date
df['year'] = pd.DatetimeIndex(df['Date']).year

# buat kolom month yang berisi hasil ekstraksi bulan pada kolom date
df['month'] = pd.DatetimeIndex(df['Date']).month

# hapus kolom Date karena sudah tidak terpakai
df = df.drop(columns="Date")

# tampilkan dataframe
df
# Out:
#                      City   PM2.5   PM10     NO    NO2    NOx   NH3     CO  \
# 0               Ahmedabad   83.13    NaN   6.93  28.71  33.72   NaN   6.93
# 1               Ahmedabad   79.84    NaN  13.85  28.68  41.08   NaN  13.85
# 2               Ahmedabad   94.52    NaN  24.39  32.66  52.61   NaN  24.39
# 3               Ahmedabad  135.99    NaN  43.48  42.08  84.57   NaN  43.48
# 4               Ahmedabad  178.33    NaN  54.56  35.31  72.80   NaN  54.56
# ...                   ...     ...    ...    ...    ...    ...   ...    ...
# 21932  Thiruvananthapuram   14.13  34.27   5.60   8.98  12.48  5.65   0.49
# 21933  Thiruvananthapuram   23.84  44.32   6.27  10.01  13.80  5.73   0.44
# 21934  Thiruvananthapuram   18.54  34.48   6.17   9.67  13.35  5.93   0.51
# 21935  Thiruvananthapuram   20.57  48.19   6.28   9.52  13.56  5.84   0.46
# 21936  Thiruvananthapuram   17.58  37.49   2.56   7.84   9.34  4.85   0.45
#
# ...

# %% [markdown]
# # Datasets Splitting

# %%
X = df.drop(columns="Air_quality")
y = df["Air_quality"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17549, 16), (4388, 16), (17549,), (4388,))

# %% [markdown]
# # Preprocessor

# %%
from xgboost import XGBClassifier

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(impute='mean', poly=None, scaling='robust', transform='yeo-johnson'), ["PM2.5","PM10","NO","NO2","NOx","NH3",
                                                                             "CO","SO2","O3","Benzene","Toluene","Xylene","AQI"]),
    ('categoric', cat_pipe(encoder='onehot'), ["City","year","month"])
])


pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', XGBClassifier(n_jobs=-1, random_state=42))
])
# Out:
# C:\Users\ROG\anaconda3\lib\site-packages\jcopml\pipeline\_pipeline.py:65: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import RandomizedSearchCV
from jcopml.tuning import random_search_params as rsp
from jcopml.tuning.space import Integer, Real

# %%
parameter_tune = {
    'algo__max_depth': Integer(low=1, high=5),
    'algo__learning_rate': Real(low=-2, high=0, prior='log-uniform'),
    'algo__n_estimators': Integer(low=100, high=200),
    'algo__subsample': Real(low=0.5, high=0.8, prior='uniform'),
    'algo__gamma': Integer(low=1, high=8),
    'algo__colsample_bytree': Real(low=0.5, high=1, prior='uniform'),
    'algo__reg_alpha': Real(low=-1, high=3, prior='log-uniform'),
    'algo__reg_lambda': Real(low=-1, high=3, prior='log-uniform')
}

# %%
model = RandomizedSearchCV(pipeline, parameter_tune, cv=3, n_iter=70, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 70 candidates, totalling 210 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:  7.6min finished
# {'algo__colsample_bytree': 0.9972789282438461, 'algo__gamma': 8, 'algo__learning_rate': 0.7058706838894105, 'algo__max_depth': 5, 'algo__n_estimators': 199, 'algo__reg_alpha': 2.4140303409654584, 'algo__reg_lambda': 27.872846096312504, 'algo__subsample': 0.6172910388310597}
# 1.0 1.0 1.0

# %%
parameter_tune = {
    'algo__max_depth': Integer(low=1, high=5),
    'algo__learning_rate': Real(low=-2, high=0, prior='log-uniform'),
    'algo__n_estimators': Integer(low=100, high=200),
    'algo__subsample': Real(low=0.5, high=0.8, prior='uniform'),
    'algo__gamma': Integer(low=1, high=8),
    'algo__colsample_bytree': Real(low=0.5, high=1, prior='uniform'),
    'algo__reg_alpha': Real(low=1, high=3, prior='log-uniform'),
    'algo__reg_lambda': Real(low=-1, high=3, prior='log-uniform')
}

model = RandomizedSearchCV(pipeline, parameter_tune, cv=3, n_iter=50, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  3.0min finished
# {'algo__colsample_bytree': 0.7188649852549424, 'algo__gamma': 8, 'algo__learning_rate': 0.0722318722243925, 'algo__max_depth': 4, 'algo__n_estimators': 174, 'algo__reg_alpha': 17.80170383218254, 'algo__reg_lambda': 26.29840640192015, 'algo__subsample': 0.6203757272176}
# 1.0 1.0 1.0

# %%
parameter_tune = {
    'algo__max_depth': Integer(low=1, high=5),
    'algo__learning_rate': Real(low=-2, high=0, prior='log-uniform'),
    'algo__n_estimators': Integer(low=100, high=200),
    'algo__subsample': Real(low=0.5, high=0.8, prior='uniform'),
    'algo__gamma': Integer(low=1, high=8),
    'algo__colsample_bytree': Real(low=0.5, high=1, prior='uniform'),
    'algo__reg_alpha': Real(low=1, high=3, prior='log-uniform'),
    'algo__reg_lambda': Real(low=-1, high=3, prior='log-uniform')
}

model = RandomizedSearchCV(pipeline, parameter_tune, cv=3, scoring='f1', n_iter=50, n_jobs=-1, verbose=2)
model.fit(X_train, y_train)

print(model.best_params_)
print(model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\ROG\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "C:\Users\ROG\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "C:\Users\ROG\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 608, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\ROG\anaconda3\lib\site-packages\joblib\parallel.py", line 256, in __call__
#     for func, args, kwargs in self.items]
# ...
