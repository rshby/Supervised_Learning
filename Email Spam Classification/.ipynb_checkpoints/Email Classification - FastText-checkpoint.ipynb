# %%
# !pip install gensim

import os

import pandas as pd

from tqdm.auto import tqdm

from nltk.tokenize import word_tokenize
from gensim.models import FastText
# Out:
# C:\Users\ROG\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\ROG\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\ROG\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# ## Prepare Corpus

# %%
df = pd.read_csv("datasets/spam_or_not_spam.csv")
df = df.loc[df["email"].notna()]
df.head()
# Out:
#                                                email  label
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0
# 1  martin a posted tassos papadopoulos the greek ...      0
# 2  man threatens explosion in moscow thursday aug...      0
# 3  klez the virus that won t die already the most...      0
# 4   in adding cream to spaghetti carbonara which ...      0

# %%
# membuat tokenize
sentences = [word_tokenize(email.lower()) for email in tqdm(df["email"])]
sentences[:5]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2999.0), HTML(value='')))
# [['date',
#   'wed',
#   'number',
#   'aug',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'from',
#   'chris',
#   'garrigues',
#   'cwg',
#   'dated',
#   'number',
#   'numberfanumberd',
#   'deepeddy',
#   'com',
#   'message',
#   'id',
#   'number',
#   'number',
#   'tmda',
#   'deepeddy',
#   'vircio',
#   'com',
#   'i',
#   'can',
#   't',
#   'reproduce',
#   'this',
#   'error',
#   'for',
#   'me',
#   'it',
#   'is',
#   'very',
#   'repeatable',
#   'like',
#   'every',
#   'time',
#   'without',
#   'fail',
#   'this',
#   'is',
#   'the',
#   'debug',
#   'log',
#   'of',
#   'the',
#   'pick',
#   'happening',
#   'number',
#   'number',
#   'number',
#   'pick_it',
#   'exec',
#   'pick',
#   'inbox',
#   'list',
#   'lbrace',
#   'lbrace',
#   'subject',
#   'ftp',
#   'rbrace',
#   'rbrace',
#   'number',
#   'number',
#   'sequence',
#   'mercury',
#   'number',
#   'number',
#   'number',
#   'exec',
#   'pick',
#   'inbox',
#   'list',
#   'lbrace',
#   'lbrace',
#   'subject',
#   'ftp',
#   'rbrace',
#   'rbrace',
#   'number',
#   'number',
#   'sequence',
#   'mercury',
#   'number',
#   'number',
#   'number',
#   'ftoc_pickmsgs',
#   'number',
#   'hit',
#   'number',
#   'number',
#   'number',
#   'marking',
#   'number',
#   'hits',
#   'number',
#   'number',
#   'number',
#   'tkerror',
#   'syntax',
#   'error',
#   'in',
#   'expression',
#   'int',
#   'note',
#   'if',
#   'i',
#   'run',
#   'the',
#   'pick',
#   'command',
#   'by',
#   'hand',
#   'delta',
#   'pick',
#   'inbox',
#   'list',
#   'lbrace',
#   'lbrace',
#   'subject',
#   'ftp',
#   'rbrace',
#   'rbrace',
#   'number',
#   'number',
#   'sequence',
#   'mercury',
#   'number',
#   'hit',
#   'that',
#   's',
#   'where',
#   'the',
#   'number',
#   'hit',
#   'comes',
#   'from',
#   'obviously',
#   'the',
#   'version',
#   'of',
#   'nmh',
#   'i',
#   'm',
#   'using',
#   'is',
#   'delta',
#   'pick',
#   'version',
#   'pick',
#   'nmh',
#   'number',
#   'number',
#   'number',
#   'compiled',
#   'on',
#   'url',
#   'at',
#   'sun',
#   'mar',
#   'number',
#   'number',
#   'number',
#   'number',
#   'ict',
#   'number',
#   'and',
#   'the',
#   'relevant',
#   'part',
#   'of',
#   'my',
#   'mh_profile',
#   'delta',
#   'mhparam',
#   'pick',
#   'seq',
#   'sel',
#   'list',
#   'since',
#   'the',
#   'pick',
#   'command',
#   'works',
#   'the',
#   'sequence',
#   'actually',
#   'both',
#   'of',
#   'them',
#   'the',
#   'one',
#   'that',
#   's',
#   'explicit',
#   'on',
#   'the',
#   'command',
#   'line',
#   'from',
#   'the',
#   'search',
#   'popup',
#   'and',
#   'the',
#   'one',
#   'that',
#   'comes',
#   'from',
#   'mh_profile',
#   'do',
#   'get',
#   'created',
#   'kre',
#   'ps',
#   'this',
#   'is',
#   'still',
#   'using',
#   'the',
#   'version',
#   'of',
#   'the',
#   'code',
#   'form',
#   'a',
#   'day',
#   'ago',
#   'i',
#   'haven',
#   't',
#   'been',
#   'able',
#   'to',
#   'reach',
#   'the',
#   'cvs',
#   'repository',
#   'today',
#   'local',
#   'routing',
#   'issue',
#   'i',
#   'think',
#   '_______________________________________________',
#   'exmh',
#   'workers',
#   'mailing',
#   'list',
#   'exmh',
#   'workers',
#   'url',
#   'url'],
#  ['martin',
#   'a',
#   'posted',
#   'tassos',
#   'papadopoulos',
#   'the',
#   'greek',
#   'sculptor',
#   'behind',
#   'the',
#   'plan',
#   'judged',
#   'that',
#   'the',
#   'limestone',
#   'of',
#   'mount',
#   'kerdylio',
#   'number',
#   'miles',
#   'east',
#   'of',
#   'salonika',
#   'and',
#   'not',
#   'far',
#   'from',
#   'the',
#   'mount',
#   'athos',
#   'monastic',
#   'community',
#   'was',
#   'ideal',
#   'for',
#   'the',
#   'patriotic',
#   'sculpture',
#   'as',
#   'well',
#   'as',
#   'alexander',
#   's',
#   'granite',
#   'features',
#   'number',
#   'ft',
#   'high',
#   'and',
#   'number',
#   'ft',
#   'wide',
#   'a',
#   'museum',
#   'a',
#   'restored',
#   'amphitheatre',
#   'and',
#   'car',
#   'park',
#   'for',
#   'admiring',
#   'crowds',
#   'are',
#   'planned',
#   'so',
#   'is',
#   'this',
#   'mountain',
#   'limestone',
#   'or',
#   'granite',
#   'if',
#   'it',
#   's',
#   'limestone',
#   'it',
#   'll',
#   'weather',
#   'pretty',
#   'fast',
#   'yahoo',
#   'groups',
#   'sponsor',
#   'number',
#   'dvds',
#   'free',
#   's',
#   'p',
#   'join',
#   'now',
#   'url',
#   'to',
#   'unsubscribe',
#   'from',
#   'this',
#   'group',
#   'send',
#   'an',
#   'email',
#   'to',
#   'forteana',
#   'unsubscribe',
#   'url',
#   'your',
#   'use',
#   'of',
#   'yahoo',
#   'groups',
#   'is',
#   'subject',
#   'to',
#   'url'],
#  ['man',
#   'threatens',
#   'explosion',
#   'in',
#   'moscow',
#   'thursday',
#   'august',
#   'number',
#   'number',
#   'number',
#   'number',
#   'pm',
#   'moscow',
#   'ap',
#   'security',
#   'officers',
#   'on',
#   'thursday',
#   'seized',
#   'an',
#   'unidentified',
#   'man',
#   'who',
#   'said',
#   'he',
#   'was',
#   'armed',
#   'with',
#   'explosives',
#   'and',
#   'threatened',
#   'to',
#   'blow',
#   'up',
#   'his',
#   'truck',
#   'in',
#   'front',
#   'of',
#   'russia',
#   's',
#   'federal',
#   'security',
#   'services',
#   'headquarters',
#   'in',
#   'moscow',
#   'ntv',
#   'television',
#   'reported',
#   'the',
#   'officers',
#   'seized',
#   'an',
#   'automatic',
#   'rifle',
#   'the',
#   'man',
#   'was',
#   'carrying',
#   'then',
#   'the',
#   'man',
#   'got',
#   'out',
#   'of',
#   'the',
#   'truck',
#   'and',
#   'was',
#   'taken',
#   'into',
#   'custody',
#   'ntv',
#   'said',
#   'no',
#   'other',
#   'details',
#   'were',
#   'immediately',
#   'available',
#   'the',
#   'man',
#   'had',
#   'demanded',
#   'talks',
#   'with',
#   'high',
#   'government',
#   'officials',
#   'the',
#   'interfax',
#   'and',
#   'itar',
#   'tass',
#   'news',
#   'agencies',
#   'said',
#   'ekho',
#   'moskvy',
#   'radio',
#   'reported',
#   'that',
#   'he',
#   'wanted',
#   'to',
#   'talk',
#   'with',
#   'russian',
#   'president',
#   'vladimir',
#   'putin',
#   'police',
#   'and',
#   'security',
#   'forces',
#   'rushed',
#   'to',
#   'the',
#   'security',
#   'service',
#   'building',
#   'within',
#   'blocks',
#   'of',
#   'the',
#   'kremlin',
#   'red',
#   'square',
#   'and',
#   'the',
#   'bolshoi',
#   'ballet',
#   'and',
#   'surrounded',
#   'the',
#   'man',
#   'who',
#   'claimed',
#   'to',
#   'have',
#   'one',
#   'and',
#   'a',
#   'half',
#   'tons',
#   'of',
#   'explosives',
#   'the',
#   'news',
#   'agencies',
#   'said',
#   'negotiations',
#   'continued',
#   'for',
#   'about',
#   'one',
#   'and',
#   'a',
#   'half',
#   'hours',
#   'outside',
#   'the',
#   'building',
#   'itar',
#   'tass',
#   'and',
#   'interfax',
#   'reported',
#   'citing',
#   'witnesses',
#   'the',
#   'man',
#   'later',
#   'drove',
#   'away',
#   'from',
#   'the',
#   'building',
#   'under',
#   'police',
#   'escort',
#   'and',
#   'drove',
#   'to',
#   'a',
#   'street',
#   'near',
#   'moscow',
#   's',
#   'olympic',
#   'penta',
#   'hotel',
#   'where',
#   'authorities',
#   'held',
#   'further',
#   'negotiations',
#   'with',
#   'him',
#   'the',
#   'moscow',
#   'police',
#   'press',
#   'service',
#   'said',
#   'the',
#   'move',
#   'appeared',
#   'to',
#   'be',
#   'an',
#   'attempt',
#   'by',
#   'security',
#   'services',
#   'to',
#   'get',
#   'him',
#   'to',
#   'a',
#   'more',
#   'secure',
#   'location',
#   'yahoo',
#   'groups',
#   'sponsor',
#   'number',
#   'dvds',
#   'free',
#   's',
#   'p',
#   'join',
#   'now',
#   'url',
#   'to',
#   'unsubscribe',
#   'from',
#   'this',
#   'group',
#   'send',
#   'an',
#   'email',
#   'to',
#   'forteana',
#   'unsubscribe',
#   'url',
#   'your',
#   'use',
#   'of',
#   'yahoo',
#   'groups',
#   'is',
#   'subject',
#   'to',
#   'url'],
#  ['klez',
#   'the',
#   'virus',
#   'that',
#   'won',
#   't',
#   'die',
#   'already',
#   'the',
#   'most',
#   'prolific',
#   'virus',
#   'ever',
#   'klez',
#   'continues',
#   'to',
#   'wreak',
#   'havoc',
#   'andrew',
#   'brandt',
#   'from',
#   'the',
#   'september',
#   'number',
#   'issue',
#   'of',
#   'pc',
#   'world',
#   'magazine',
#   'posted',
#   'thursday',
#   'august',
#   'number',
#   'number',
#   'the',
#   'klez',
#   'worm',
#   'is',
#   'approaching',
#   'its',
#   'seventh',
#   'month',
#   'of',
#   'wriggling',
#   'across',
#   'the',
#   'web',
#   'making',
#   'it',
#   'one',
#   'of',
#   'the',
#   'most',
#   'persistent',
#   'viruses',
#   'ever',
#   'and',
#   'experts',
#   'warn',
#   'that',
#   'it',
#   'may',
#   'be',
#   'a',
#   'harbinger',
#   'of',
#   'new',
#   'viruses',
#   'that',
#   'use',
#   'a',
#   'combination',
#   'of',
#   'pernicious',
#   'approaches',
#   'to',
#   'go',
#   'from',
#   'pc',
#   'to',
#   'pc',
#   'antivirus',
#   'software',
#   'makers',
#   'symantec',
#   'and',
#   'mcafee',
#   'both',
#   'report',
#   'more',
#   'than',
#   'number',
#   'new',
#   'infections',
#   'daily',
#   'with',
#   'no',
#   'sign',
#   'of',
#   'letup',
#   'at',
#   'press',
#   'time',
#   'the',
#   'british',
#   'security',
#   'firm',
#   'messagelabs',
#   'estimates',
#   'that',
#   'number',
#   'in',
#   'every',
#   'number',
#   'e',
#   'mail',
#   'messages',
#   'holds',
#   'a',
#   'variation',
#   'of',
#   'the',
#   'klez',
#   'virus',
#   'and',
#   'says',
#   'that',
#   'klez',
#   'has',
#   'already',
#   'surpassed',
#   'last',
#   'summer',
#   's',
#   'sircam',
#   'as',
#   'the',
#   'most',
#   'prolific',
#   'virus',
#   'ever',
#   'and',
#   'some',
#   'newer',
#   'klez',
#   'variants',
#   'aren',
#   't',
#   'merely',
#   'nuisances',
#   'they',
#   'can',
#   'carry',
#   'other',
#   'viruses',
#   'in',
#   'them',
#   'that',
#   'corrupt',
#   'your',
#   'data',
#   'url',
#   '_______________________________________________',
#   'irregulars',
#   'mailing',
#   'list',
#   'irregulars',
#   'url',
#   'url'],
#  ['in',
#   'adding',
#   'cream',
#   'to',
#   'spaghetti',
#   'carbonara',
#   'which',
#   'has',
#   'the',
#   'same',
#   'effect',
#   'on',
#   'pasta',
#   'as',
#   'making',
#   'a',
#   'pizza',
#   'a',
#   'deep',
#   'pie',
#   'i',
#   'just',
#   'had',
#   'to',
#   'jump',
#   'in',
#   'here',
#   'as',
#   'carbonara',
#   'is',
#   'one',
#   'of',
#   'my',
#   'favourites',
#   'to',
#   'make',
#   'and',
#   'ask',
#   'what',
#   'the',
#   'hell',
#   'are',
#   'you',
#   'supposed',
#   'to',
#   'use',
#   'instead',
#   'of',
#   'cream',
#   'i',
#   've',
#   'never',
#   'seen',
#   'a',
#   'recipe',
#   'that',
#   'hasn',
#   't',
#   'used',
#   'this',
#   'personally',
#   'i',
#   'use',
#   'low',
#   'fat',
#   'creme',
#   'fraiche',
#   'because',
#   'it',
#   'works',
#   'quite',
#   'nicely',
#   'but',
#   'the',
#   'only',
#   'time',
#   'i',
#   've',
#   'seen',
#   'an',
#   'supposedly',
#   'authentic',
#   'recipe',
#   'for',
#   'carbonara',
#   'it',
#   'was',
#   'identical',
#   'to',
#   'mine',
#   'cream',
#   'eggs',
#   'and',
#   'lots',
#   'of',
#   'fresh',
#   'parmesan',
#   'except',
#   'for',
#   'the',
#   'creme',
#   'fraiche',
#   'stew',
#   'stewart',
#   'smith',
#   'scottish',
#   'microelectronics',
#   'centre',
#   'university',
#   'of',
#   'edinburgh',
#   'url',
#   'yahoo',
#   'groups',
#   'sponsor',
#   'number',
#   'dvds',
#   'free',
#   's',
#   'p',
#   'join',
#   'now',
#   'url',
#   'to',
#   'unsubscribe',
#   'from',
#   'this',
#   'group',
#   'send',
#   'an',
#   'email',
#   'to',
#   'forteana',
#   'unsubscribe',
#   'url',
#   'your',
#   'use',
#   'of',
#   'yahoo',
#   'groups',
#   'is',
#   'subject',
#   'to',
#   'url']]

# %% [markdown]
# ## Train Model FastText

# %%
model = Word2Vec(sentences, size=128, window=5, min_count=3, workers=4, iter=800, sg=0, hs=0)

# %% [markdown]
# ## Save Model

# %%
os.makedirs("model/w2v/", exist_ok=True)
model.save("model/w2v/email_spam.w2v")

# %% [markdown]
# ## Load Model

# %%
model = Word2Vec.load("model/w2v/email_spam.w2v")

# %% [markdown]
# ## Model Information

# %%
w2v = model.wv

# %%
w2v.index2word
# Out:
# ['number',
#  'the',
#  'to',
#  'and',
#  'of',
#  'a',
#  'in',
#  'i',
#  'url',
#  'is',
#  'that',
#  'you',
#  'it',
#  'for',
#  'this',
#  'on',
#  's',
#  'with',
#  'be',
#  'not',
#  'have',
#  'are',
#  'from',
#  'as',
#  't',
#  'or',
#  'your',
#  'at',
#  'by',
#  'if',
#  'but',
#  'we',
#  'can',
#  'was',
#  'an',
#  'all',
#  'will',
#  'list',
#  'my',
#  'they',
#  'so',
#  'has',
#  'one',
#  'do',
#  'more',
#  'there',
#  'get',
#  'our',
#  'no',
#  'just',
#  'out',
#  'about',
#  'what',
#  'which',
#  'people',
#  'time',
#  'their',
#  'up',
#  'use',
#  'would',
#  'only',
#  'like',
#  'new',
#  'he',
#  'who',
#  'any',
#  'free',
#  'email',
#  'now',
#  'some',
#  'me',
#  'when',
#  'don',
#  'other',
#  'mail',
#  'here',
#  'been',
#  'm',
#  'than',
#  'how',
#  'them',
#  'wrote',
#  'also',
#  'rpm',
#  'e',
#  'then',
#  'make',
#  'mailing',
#  'date',
#  'message',
#  'world',
#  'said',
#  'had',
#  'us',
#  'his',
#  'because',
#  'hyperlink',
#  'into',
#  're',
#  'over',
#  'spamassassin',
#  'its',
#  'd',
#  'way',
#  'were',
#  'money',
#  'first',
#  'could',
#  'users',
#  'information',
#  'these',
#  'think',
#  'should',
#  've',
#  'work',
#  '_______________________________________________',
#  'even',
#  'most',
#  'c',
#  'spam',
#  'know',
#  'want',
#  'see',
#  'please',
#  'may',
#  'where',
#  'exmh',
#  'after',
#  'much',
#  'using',
#  'well',
#  'same',
#  'those',
#  'business',
#  'many',
#  'll',
#  'linux',
#  'need',
#  'does',
#  'good',
#  'send',
#  'go',
#  'very',
#  'line',
#  'years',
#  'home',
#  'am',
#  'right',
#  'before',
#  'such',
#  'subject',
#  'being',
#  'government',
#  'take',
#  'through',
#  'internet',
#  'group',
#  'still',
#  'file',
#  'find',
#  'net',
#  'states',
#  'two',
#  'own',
#  'name',
#  'help',
#  'click',
#  'system',
#  'razor',
#  'data',
#  'best',
#  'something',
#  'software',
#  'too',
#  'sep',
#  'com',
#  'really',
#  'day',
#  'web',
#  'address',
#  'every',
#  'company',
#  'problem',
#  'change',
#  'old',
#  'few',
#  'each',
#  'since',
#  'messages',
#  'made',
#  'used',
#  'year',
#  'report',
#  'why',
#  'today',
#  'must',
#  'say',
#  'back',
#  'talk',
#  'while',
#  'down',
#  'united',
#  'last',
#  'check',
#  'without',
#  'did',
#  'unsubscribe',
#  'long',
#  'off',
#  'phone',
#  'sure',
#  'run',
#  'state',
#  'better',
#  'next',
#  'set',
#  'order',
#  'sent',
#  'numbertnumber',
#  'got',
#  'doesn',
#  'found',
#  'real',
#  'another',
#  'fork',
#  'link',
#  'f',
#  'perl',
#  'again',
#  'l',
#  'life',
#  'going',
#  'security',
#  'might',
#  'files',
#  'never',
#  'once',
#  'anyone',
#  'x',
#  'receive',
#  'code',
#  'give',
#  'end',
#  'different',
#  'within',
#  'look',
#  'she',
#  'try',
#  'mr',
#  'case',
#  'things',
#  'great',
#  'r',
#  'companies',
#  'program',
#  'million',
#  'against',
#  'computer',
#  'u',
#  'service',
#  'september',
#  'technology',
#  'actually',
#  'high',
#  'server',
#  'her',
#  'package',
#  'groups',
#  'both',
#  'etc',
#  'thing',
#  'original',
#  'based',
#  'probably',
#  'part',
#  'news',
#  'version',
#  'point',
#  'received',
#  'de',
#  'mailto',
#  'between',
#  'error',
#  'yes',
#  'keep',
#  'sponsored',
#  'read',
#  'yahoo',
#  'put',
#  'someone',
#  'under',
#  'per',
#  'freshrpms',
#  'less',
#  'anything',
#  'around',
#  'start',
#  'user',
#  'support',
#  'come',
#  'easy',
#  'times',
#  'build',
#  'didn',
#  'done',
#  'site',
#  'form',
#  'president',
#  'running',
#  'apt',
#  'let',
#  'text',
#  'seems',
#  'market',
#  'looking',
#  'access',
#  'american',
#  'working',
#  'remove',
#  'call',
#  'war',
#  'network',
#  'though',
#  'matthias',
#  'country',
#  'least',
#  'ever',
#  'kernel',
#  'type',
#  'future',
#  'thanks',
#  'course',
#  'following',
#  'un',
#  'services',
#  'html',
#  'lot',
#  'stuff',
#  'doing',
#  'available',
#  'public',
#  'bush',
#  'below',
#  'trade',
#  'xml',
#  'offer',
#  'says',
#  'however',
#  'wish',
#  'current',
#  'release',
#  'w',
#  'instead',
#  'else',
#  'place',
#  'trying',
#  'content',
#  'non',
#  'folder',
#  'b',
#  'little',
#  '_',
#  'p',
#  'red',
#  'problems',
#  'won',
#  'days',
#  'supplied',
#  'maybe',
#  'page',
#  'getting',
#  'source',
#  'test',
#  'log',
#  'nothing',
#  'root',
#  'works',
#  'idea',
#  'aug',
#  'week',
#  'removed',
#  'far',
#  'yet',
#  'always',
#  'law',
#  'enough',
#  'pm',
#  'america',
#  'open',
#  'him',
#  'rights',
#  'already',
#  'isn',
#  'add',
#  'online',
#  'price',
#  'key',
#  'making',
#  'total',
#  'global',
#  'big',
#  'example',
#  'possible',
#  'special',
#  'called',
#  'subscription',
#  'o',
#  'local',
#  'admin',
#  'contact',
#  'numbers',
#  'pay',
#  'having',
#  'national',
#  'top',
#  'thought',
#  'cd',
#  'alsa',
#  'including',
#  'irish',
#  'communications',
#  'either',
#  'n',
#  'three',
#  'person',
#  'hat',
#  'fact',
#  'ilug',
#  'simple',
#  'full',
#  'political',
#  'marketing',
#  'discuss',
#  'able',
#  'seen',
#  'second',
#  'show',
#  'packages',
#  'tell',
#  'development',
#  'investment',
#  'provide',
#  'others',
#  'include',
#  'important',
#  'writes',
#  'until',
#  'buy',
#  'install',
#  'friends',
#  'personal',
#  'large',
#  'live',
#  'tried',
#  'installed',
#  'usr',
#  'experience',
#  'legal',
#  'international',
#  'issue',
#  'man',
#  'power',
#  'months',
#  'windows',
#  'small',
#  'ago',
#  'away',
#  'true',
#  'maintainer',
#  'believe',
#  'sites',
#  'save',
#  'further',
#  'hard',
#  'redhat',
#  'cash',
#  'addresses',
#  'bit',
#  'family',
#  'rather',
#  'systems',
#  'women',
#  'wrong',
#  'act',
#  'during',
#  'story',
#  'dollars',
#  'month',
#  'listmaster',
#  'lists',
#  'often',
#  'grants',
#  'alb',
#  'move',
#  'upon',
#  'receiving',
#  'industry',
#  'g',
#  'product',
#  'stop',
#  'j',
#  'hours',
#  'h',
#  'ok',
#  'http',
#  'seem',
#  'financial',
#  'programs',
#  'policy',
#  'become',
#  'account',
#  'remember',
#  'means',
#  'above',
#  'past',
#  'opportunity',
#  'countries',
#  'via',
#  'office',
#  'control',
#  'given',
#  'box',
#  'income',
#  'value',
#  'reason',
#  'kind',
#  'bad',
#  'drive',
#  'chris',
#  'search',
#  'deal',
#  'allow',
#  'simply',
#  'whether',
#  'results',
#  'currently',
#  'unseen',
#  'forteana',
#  'quite',
#  'freedom',
#  'job',
#  'directory',
#  'inumber',
#  'economic',
#  'en',
#  'word',
#  'process',
#  'guide',
#  'cell',
#  'devel',
#  'whole',
#  'ham',
#  'everything',
#  'info',
#  'training',
#  'center',
#  'half',
#  'makes',
#  'question',
#  'welcome',
#  'dvd',
#  'orders',
#  'nice',
#  'went',
#  'card',
#  'copy',
#  'understand',
#  'several',
#  'lost',
#  'reply',
#  'city',
#  'complete',
#  'mind',
#  'came',
#  'wed',
#  'post',
#  'credit',
#  'java',
#  'mean',
#  'interest',
#  'step',
#  'later',
#  'fax',
#  'rate',
#  'hit',
#  'john',
#  'size',
#  'datapower',
#  'workers',
#  'august',
#  'cost',
#  'general',
#  'copyright',
#  'sell',
#  'mails',
#  'pretty',
#  'human',
#  'database',
#  'learn',
#  'single',
#  'easily',
#  'return',
#  'rates',
#  'thousands',
#  'capital',
#  'write',
#  'needed',
#  'tired',
#  'almost',
#  'k',
#  'love',
#  'sending',
#  'needs',
#  'level',
#  'false',
#  'bill',
#  'anyway',
#  'share',
#  'response',
#  'bank',
#  'application',
#  'looks',
#  'preferences',
#  'private',
#  'names',
#  'gets',
#  'men',
#  'numberpm',
#  'party',
#  'low',
#  'mon',
#  'although',
#  'plus',
#  'weeks',
#  'force',
#  'plan',
#  'federal',
#  'told',
#  'thu',
#  'google',
#  'exactly',
#  'ideas',
#  'interested',
#  'networks',
#  'major',
#  'fast',
#  'book',
#  'known',
#  'load',
#  'hi',
#  'risk',
#  'hand',
#  'join',
#  'daily',
#  'signature',
#  'client',
#  'reports',
#  'digital',
#  'window',
#  'similar',
#  'inc',
#  'recent',
#  'due',
#  'self',
#  'enenkio',
#  'note',
#  'added',
#  'perhaps',
#  'required',
#  'foreign',
#  'words',
#  'area',
#  'products',
#  'started',
#  'geek',
#  'performance',
#  'military',
#  'feel',
#  'sa',
#  'left',
#  'emails',
#  'offers',
#  'growing',
#  'base',
#  'heaven',
#  'posted',
#  'article',
#  'create',
#  'cvs',
#  'sex',
#  'numberth',
#  'insurance',
#  'rules',
#  'management',
#  'dave',
#  'lines',
#  'lib',
#  'header',
#  'happy',
#  'worth',
#  'bug',
#  'play',
#  'visit',
#  'wanted',
#  'reading',
#  'osdn',
#  'monday',
#  'thinking',
#  'protect',
#  'processing',
#  'sun',
#  'across',
#  'changed',
#  'research',
#  'everyone',
#  'along',
#  'beberg',
#  'domain',
#  'building',
#  'website',
#  'partners',
#  'term',
#  'feature',
#  'school',
#  'clear',
#  'oct',
#  'nations',
#  'tim',
#  'msgs',
#  'procmail',
#  'mark',
#  'latest',
#  'air',
#  'matter',
#  'machine',
#  'interesting',
#  'behalf',
#  'configure',
#  'python',
#  'recently',
#  'begin',
#  'continue',
#  'headers',
#  'administration',
#  'india',
#  'powell',
#  'amount',
#  'answer',
#  'saou',
#  'immediately',
#  'street',
#  'secure',
#  'robert',
#  'increase',
#  'york',
#  'language',
#  'house',
#  'transaction',
#  'nation',
#  'october',
#  'claim',
#  'yourself',
#  'thinkgeek',
#  'pgp',
#  'goes',
#  'action',
#  'hope',
#  'includes',
#  'living',
#  'os',
#  'respect',
#  'professional',
#  'soon',
#  'body',
#  'et',
#  'mass',
#  'adam',
#  'bitbitch',
#  'letter',
#  'social',
#  'select',
#  'community',
#  'university',
#  'space',
#  'society',
#  'five',
#  'worked',
#  'together',
#  'short',
#  'project',
#  'method',
#  'ask',
#  'fine',
#  'update',
#  'tools',
#  'device',
#  'regards',
#  'game',
#  'limited',
#  'finally',
#  'sponsor',
#  'direct',
#  'specific',
#  'hardware',
#  'especially',
#  'care',
#  'average',
#  'assistance',
#  'islands',
#  'comes',
#  'except',
#  'guess',
#  'early',
#  'face',
#  'thank',
#  'media',
#  'sort',
#  'lawrence',
#  'absolutely',
#  'customers',
#  'press',
#  'paid',
#  'longer',
#  'fall',
#  'v',
#  'design',
#  'black',
#  'sound',
#  'main',
#  'potential',
#  'whatever',
#  'finding',
#  'coming',
#  'ability',
#  'third',
#  'success',
#  'late',
#  'common',
#  'entire',
#  'usa',
#  'kingdom',
#  'taken',
#  'history',
#  'standard',
#  'white',
#  'gary',
#  'echo',
#  'built',
#  'itself',
#  'cc',
#  'wasn',
#  'issues',
#  'saying',
#  'tied',
#  'wants',
#  'talking',
#  'particular',
#  'happen',
#  'links',
#  'corporation',
#  'fill',
#  'forces',
#  'took',
#  'follow',
#  'clean',
#  'custom',
#  'china',
#  'changes',
#  'oh',
#  'unless',
#  'tue',
#  'hettinga',
#  'command',
#  'haven',
#  'health',
#  'advertising',
#  'heard',
#  'washington',
#  'platform',
#  'fund',
#  'lots',
#  'applications',
#  'choice',
#  'quality',
#  'q',
#  'asked',
#  'ways',
#  'tuesday',
#  'six',
#  'father',
#  'trading',
#  'spamd',
#  'opt',
#  'french',
#  'night',
#  'close',
#  'various',
#  'spec',
#  'rah',
#  'rh',
#  'rule',
#  'secret',
#  'record',
#  'wouldn',
#  'rest',
#  'contains',
#  'numberk',
#  'rss',
#  'pick',
#  'likely',
#  'included',
#  'view',
#  'according',
#  'request',
#  'head',
#  'department',
#  'gives',
#  'requires',
#  'member',
#  'hundreds',
#  'questions',
#  'invoked',
#  'skip',
#  'car',
#  'congress',
#  'property',
#  'agree',
#  'transfer',
#  'members',
#  'notice',
#  'willing',
#  'opportunities',
#  'details',
#  'sense',
#  'script',
#  'useful',
#  'happened',
#  'folks',
#  'advantage',
#  'cause',
#  'south',
#  'james',
#  'terrorism',
#  'death',
#  'friend',
#  'individuals',
#  'writing',
#  'knowledge',
#  'turn',
#  'pacific',
#  'agent',
#  'forward',
#  'grant',
#  'membership',
#  'mime',
#  'completely',
#  'driver',
#  'speech',
#  'figure',
#  'murphy',
#  'benefit',
#  'taking',
#  'hour',
#  'successful',
#  'quick',
#  'valuable',
#  'forwarded',
#  'takes',
#  'effort',
#  'certainly',
#  'paste',
#  'sales',
#  'instructions',
#  'shipping',
#  'purchase',
#  'americans',
#  'dr',
#  'stock',
#  'decided',
#  'selling',
#  'age',
#  'exist',
#  'side',
#  'related',
#  'music',
#  'servers',
#  'co',
#  'memory',
#  'paper',
#  'button',
#  'energy',
#  'id',
#  'reach',
#  'dvds',
#  'police',
#  'young',
#  'whose',
#  'terms',
#  'solution',
#  'score',
#  ...]

# %%
w2v.vectors
# Out:
# array([[-0.48425394, -2.4420595 ,  0.57668823, ..., -3.209725  ,
#          1.1528778 , -1.0570666 ],
#        [-0.9712879 , -0.11089331, -1.4091527 , ..., -0.78666264,
#         -0.25651205,  2.0329738 ],
#        [-1.3585579 , -2.0334811 , -2.9978566 , ..., -1.1884505 ,
#          0.36884072,  0.89595515],
#        ...,
#        [-1.2237101 ,  1.1278837 ,  0.06294397, ...,  0.9311315 ,
#         -0.22662179, -4.587529  ],
#        [-0.1028017 ,  1.4032881 , -1.01217   , ...,  1.4370338 ,
#         -0.0281599 , -3.6900573 ],
#        [-0.11113238, -0.07932117, -1.0202459 , ...,  0.8643712 ,
#         -0.5111585 , -5.549954  ]], dtype=float32)

# %%
w2v.vector_size
# Out:
# 128

# %%
w2v["online"]
# Out:
# array([ 3.1251576 ,  1.6283026 ,  1.3168931 ,  1.0806856 ,  0.6165383 ,
#         1.4555733 , -2.9434695 , -2.6267276 , -0.7347846 , -0.63291854,
#        -0.42770213, -1.6969575 , -0.7420905 ,  3.5092707 , -5.3976665 ,
#         3.4823084 ,  2.223181  , -0.4290541 ,  0.8436355 , -6.3392367 ,
#        -0.20925023,  3.296211  ,  2.2208211 , -0.27603784, -0.89867795,
#        -1.2270781 , -0.9215378 ,  4.2275267 , -2.0149496 ,  1.6046672 ,
#         0.70325816,  1.3176095 ,  0.36537904,  1.5368588 ,  4.462055  ,
#         3.673685  ,  4.5297174 ,  0.47667426,  4.273858  ,  1.3359423 ,
#         0.18882078,  0.19374351, -2.792836  , -1.4162123 ,  0.08573525,
#         0.4580659 ,  0.83232737, -0.08674087, -3.3137245 ,  1.0465537 ,
#         2.4803734 , -1.8778602 ,  2.735989  , -0.5030345 , -1.3576709 ,
#        -3.789288  , -0.647946  , -0.84428805, -2.2344751 , -1.7749156 ,
#        -2.4141164 , -2.754965  ,  4.9356523 , -3.4935641 ,  4.2265286 ,
#         4.783513  ,  0.01864129, -1.326966  , -4.048335  , -1.7490704 ,
#        -0.1770349 , -3.203781  ,  4.2348366 , -0.53286916, -1.2988071 ,
#        -0.2402387 , -0.93566674, -1.0612236 ,  0.15142885,  2.6026368 ,
#        -6.3556724 ,  0.695536  ,  0.27197373,  0.18511741,  6.5762653 ,
#         3.7008798 , -5.99637   , -0.06484069,  2.4535217 , -0.8320961 ,
#        -5.0466256 ,  0.25182098, -4.625414  ,  4.394945  ,  1.8312098 ,
#         0.19030333, -1.9345188 ,  2.6102302 ,  5.0372787 ,  1.6710001 ,
#         3.5575094 ,  1.9160688 , -0.70573515,  2.7252502 ,  2.5770543 ,
#         0.32442915, -2.2089295 , -6.8511286 , -3.455462  ,  2.043007  ,
#        -0.8279134 ,  1.6661509 ,  3.6621802 , -5.037561  , -2.9859147 ,
#        -2.5572264 , -2.3230975 , -1.0484731 , -0.601252  , -3.7240431 ,
#         4.783953  , -1.1641905 ,  2.0235333 , -1.2017612 ,  4.949599  ,
#        -2.4682415 ,  2.526424  , -5.2089767 ], dtype=float32)

# %% [markdown]
# ## Sanity Check
# ### Similar word

# %%
w2v.similar_by_word("me", topn=5)
# Out:
# [('us', 0.5087110996246338),
#  ('it', 0.41770100593566895),
#  ('him', 0.40021273493766785),
#  ('i', 0.39329099655151367),
#  ('you', 0.380694180727005)]

# %% [markdown]
# ### Higher order visualization

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
X = UMAP().fit_transform(w2v.vectors)

# %%
df = pd.DataFrame(X, columns=["umap1", "umap2"])
df["email"] = w2v.index2word
df
# Out:
#           umap1     umap2       email
# 0     -0.893471 -1.049520      number
# 1      2.874886 -1.943764         the
# 2      2.964265 -1.906687          to
# 3      2.723575 -1.750905         and
# 4      2.692146 -1.775527          of
# ...         ...       ...         ...
# 13588  0.594567  1.170084     desmond
# 13589 -0.618637  1.550405           幔
# 13590 -1.799637 -2.250500         件地址
# 13591 -2.608686 -2.241816  yhzxnumber
# 13592 -1.809453 -2.200183        y河之星
#
# [13593 rows x 3 columns]

# %%
fig = px.scatter(df, x="umap1", y="umap2", text="email")
fig.update_traces(textposition='top center')
fig.update_layout(
    height=800,
    title_text="Reduce W2V Visualization"
)
fig.show()
# Out:
# <div>                            <div id="c6d77571-92e2-4399-94dc-f9ef338c883b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6d77571-92e2-4399-94dc-f9ef338c883b")) {                    Plotly.newPlot(                        "c6d77571-92e2-4399-94dc-f9ef338c883b",                        [{"hovertemplate": "umap1=%{x}<br>umap2=%{y}<br>email=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers+text", "name": "", "showlegend": false, "text": ["number", "the", "to", "and", "of", "a", "in", "i", "url", "is", "that", "you", "it", "for", "this", "on", "s", "with", "be", "not", "have", "are", "from", "as", "t", "or", "your", "at", "by", "if", "but", "we", "can", "was", "an", "all", "will", "list", "my", "they", "so", "has", "one", "do", "more", "there", "get", "our", "no", "just", "out", "about", "what", "which", "people", "time", "their", "up", "use", "would", "only", "like", "new", "he", "who", "any", "free", "email", "now", "some", "me", "when", "don", "other", "mail", "here", "been", "m", "than", "how", "them", "wrote", "also", "rpm", "e", "then", "make", "mailing", "date", "message", "world", "said", "had", "us", "his", "because", "hyperlink", "into", "re", "over", "spamassassin", "its", "d", "way", "were", "money", "first", "could", "users", "information", "these", "think", "should", "ve", "work", "_______________________________________________", "even", "most", "c", "spam", "know", "want", "see", "please", "may", "where", "exmh", "after", "much", "using", "well", "same", "those", "business", "many", "ll", "linux", "need", "does", "good", "send", "go", "very", "line", "years", "home", "am", "right", "before", "such", "subject", "being", "government", "take", "through", "internet", "group", "still", "file", "find", "net", "states", "two", "own", "name", "help", "click", "system", "razor", "data", "best", "something", "software", "too", "sep", "com", "really", "day", "web", "address", "every", "company", "problem", "change", "old", "few", "each", "since", "messages", "made", "used", "year", "report", "why", "today", "must", "say", "back", "talk", "while", "down", "united", "last", "check", "without", "did", "unsubscribe", "long", "off", "phone", "sure", "run", "state", "better", "next", "set", "order", "sent", "numbertnumber", "got", "doesn", "found", "real", "another", "fork", "link", "f", "perl", "again", "l", "life", "going", "security", "might", "files", "never", "once", "anyone", "x", "receive", "code", "give", "end", "different", "within", "look", "she", "try", "mr", "case", "things", "great", "r", "companies", "program", "million", "against", "computer", "u", "service", "september", "technology", "actually", "high", "server", "her", "package", "groups", "both", "etc", "thing", "original", "based", "probably", "part", "news", "version", "point", "received", "de", "mailto", "between", "error", "yes", "keep", "sponsored", "read", "yahoo", "put", "someone", "under", "per", "freshrpms", "less", "anything", "around", "start", "user", "support", "come", "easy", "times", "build", "didn", "done", "site", "form", "president", "running", "apt", "let", "text", "seems", "market", "looking", "access", "american", "working", "remove", "call", "war", "network", "though", "matthias", "country", "least", "ever", "kernel", "type", "future", "thanks", "course", "following", "un", "services", "html", "lot", "stuff", "doing", "available", "public", "bush", "below", "trade", "xml", "offer", "says", "however", "wish", "current", "release", "w", "instead", "else", "place", "trying", "content", "non", "folder", "b", "little", "_", "p", "red", "problems", "won", "days", "supplied", "maybe", "page", "getting", "source", "test", "log", "nothing", "root",  ...
